# %%
import pandas as pd
data = pd.read_csv("/Users/heng/Data_Base/project/Coach_data/total_coach")

# %%
data
# Out:
#      Coach_ID    Fname        Lname                      Position  Team_ID
# 0           0    Dwane        Casey                    Head Coach      4.0
# 1           1      Rex     Kalamian               Assistant Coach      4.0
# 2           2     Nick        Nurse               Assistant Coach      4.0
# 3           3     Jama    Mahlalela               Assistant Coach      4.0
# 4           4      Jim         Sann               Assistant Coach      4.0
# 5           5  Patrick      Mutombo               Assistant Coach      4.0
# 6           6     John   McCullough                       Trainer      4.0
# 7           7     Alex    McKechnie     Strength and Conditioning      4.0
# 8           8    Scott   McCullough                       Trainer      4.0
# 9           9     Brad      Stevens                    Head Coach      0.0
# 10         10      Jay    Larranaga               Assistant Coach      0.0
# ...
